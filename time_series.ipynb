# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("retweets.csv",index_col=0, dtype={'author_id':str})
# df = pd.read_csv("retweets.csv",index_col=0)

# %%
df
# Out:
#                    author_id                 created_at                   id  \
# 0        1417148229053988879  2021-10-07 00:12:23+00:00  1445904805852033026
# 1        1376715806235561984  2021-10-07 00:11:27+00:00  1445904569066786817
# 2        1441084185653829644  2021-10-07 00:12:12+00:00  1445904758074654720
# 3        1386666107994583045  2021-10-07 00:11:20+00:00  1445904541019475969
# 4                  423895213  2021-10-07 00:11:17+00:00  1445904527010369536
# ...                      ...                        ...                  ...
# 1145702           2678455944  2021-10-07 00:00:08+00:00  1445901720026976256
# 1145703            633330070  2021-10-07 00:00:05+00:00  1445901707251175427
# 1145704  1051634101390856193  2021-10-07 00:00:04+00:00  1445901705695088640
# 1145705            316918405  2021-10-07 00:00:02+00:00  1445901696979308550
# 1145706  1058014331420450817  2021-10-07 00:00:00+00:00  1445901686007078913
#
#                                                       text  \
# 0        RT @MarcosRogerio: O relator informou que colo...
# 1        RT @MarcosRogerio: O relator informou que colo...
# 2        RT @MarcosRogerio: O relator informou que colo...
# 3        RT @MarcosRogerio: O relator informou que colo...
# 4        RT @MarcosRogerio: O relator informou que colo...
# ...                                                    ...
# 1145702  RT @GFiuza_Oficial: Mais uma: Sofia, 17 anos, ...
# 1145703  RT @monicabergamo: O "kit Covid", pacote de re...
# 1145704  RT @simoneregazio: Meu amor vcs aplaudiram reu...
# 1145705  RT @BarbeariaPoian: A Suécia interrompe o uso ...
# 1145706  RT @AiltonBenedito: Infectados são capazes de ...
#
#         referenced_tweets_type  referenced_tweets_id  \
# 0                    retweeted   1445890361688313856
# 1                    retweeted   1445890361688313856
# 2                    retweeted   1445890361688313856
# 3                    retweeted   1445890361688313856
# 4                    retweeted   1445890361688313856
# ...                        ...                   ...
# 1145702              retweeted   1444772527084130304
# 1145703              retweeted   1445884696320266241
# 1145704              retweeted   1445883224710946820
# 1145705              retweeted   1445734811453247489
# 1145706              retweeted   1445730455966334976
#
#                  author_created_at  \
# 0        2021-07-19 15:44:25+00:00
# 1        2021-03-30 02:00:22+00:00
# 2        2021-09-23 16:57:17+00:00
# 3        2021-04-26 12:59:10+00:00
# 4        2011-11-29 02:21:10+00:00
# ...                            ...
# 1145702  2014-07-25 02:35:43+00:00
# 1145703  2012-07-12 00:23:54+00:00
# 1145704  2018-10-15 00:41:22+00:00
# 1145705  2011-06-14 04:48:00+00:00
# 1145706  2018-11-01 15:14:08+00:00
#
#                                              author_name  author_username  \
# 0                                                    EaS      EaS33130022
# 1                                          Filipe Vianna    _DireitaUnida
# 2                                       EmersonFernandez  Emerson79311981
# 3                                          Sérgio Morais   SergioMorais38
# 4                                            Edmir Silva      EdmirSilva1
# ...                                                  ...              ...
# 1145702  MANOEL MOURA ............................BRAZIL     MANOELMOURA1
# 1145703                              Luciana de Oliveira      LubraulioDe
# 1145704                                     Lalo Proenca      LaloProenca
# 1145705             Thiago🇧🇷 BOLSONARO.🔰 🪂 FORÇA E AÇÃO!       Thiago_CIR
# 1145706                          João Aristóteles 🔰🗡🇧🇷🗡🔰   AristotelesVia
#
#          referenced_tweets_author_id referenced_tweets_created_at  \
# 0                          160895960    2021-10-06 23:15:00+00:00
# 1                          160895960    2021-10-06 23:15:00+00:00
# 2                          160895960    2021-10-06 23:15:00+00:00
# 3                          160895960    2021-10-06 23:15:00+00:00
# 4                          160895960    2021-10-06 23:15:00+00:00
# ...                              ...                          ...
# 1145702                   2804949532    2021-10-03 21:13:07+00:00
# 1145703                     58951368    2021-10-06 22:52:29+00:00
# 1145704           771574989195575302    2021-10-06 22:46:38+00:00
# 1145705                   2802207875    2021-10-06 12:56:54+00:00
# 1145706                    342403919    2021-10-06 12:39:35+00:00
#
#                                     referenced_tweets_text  \
# 0        O relator informou que colocará o presidente d...
# 1        O relator informou que colocará o presidente d...
# 2        O relator informou que colocará o presidente d...
# 3        O relator informou que colocará o presidente d...
# 4        O relator informou que colocará o presidente d...
# ...                                                    ...
# 1145702  Mais uma: Sofia, 17 anos, estudante saudável, ...
# 1145703  O "kit Covid", pacote de remédios ineficazes c...
# 1145704  Meu amor vcs aplaudiram reunião  com Amado Bat...
# 1145705  A Suécia interrompe o uso de 💉💉💉 da covid  par...
# 1145706  Infectados são capazes de gerar anticorpos con...
#
#         referenced_tweets_author_created_at referenced_tweets_author_name  \
# 0                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 1                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 2                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 3                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 4                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# ...                                     ...                           ...
# 1145702           2014-10-04 13:20:53+00:00               Guilherme Fiuza
# 1145703           2009-07-21 22:55:27+00:00                Mônica Bergamo
# 1145704           2016-09-02 05:06:27+00:00              Simone Regazio 🚩
# 1145705           2014-10-03 16:22:22+00:00       Verdades e Nada Mais 🔸️
# 1145706           2011-07-25 23:37:38+00:00             🇧🇷Ailton Benedito
#
#         referenced_tweets_author_username
# 0                           MarcosRogerio
# 1                           MarcosRogerio
# 2                           MarcosRogerio
# 3                           MarcosRogerio
# 4                           MarcosRogerio
# ...                                   ...
# 1145702                    GFiuza_Oficial
# 1145703                     monicabergamo
# 1145704                     simoneregazio
# 1145705                    BarbeariaPoian
# 1145706                    AiltonBenedito
#
# [1145707 rows x 15 columns]

# %%
# df["created_at"] = df["created_at"].apply(datetime.fromisoformat)
# df["author_created_at"] = df["author_created_at"].apply(datetime.fromisoformat)
# df["referenced_tweets_created_at"] = df["referenced_tweets_created_at"].apply(datetime.fromisoformat)
# df["referenced_tweets_author_created_at"] = df["referenced_tweets_author_created_at"].apply(datetime.fromisoformat)

df[["created_at","author_created_at","referenced_tweets_created_at","referenced_tweets_author_created_at"]] = df[["created_at","author_created_at","referenced_tweets_created_at","referenced_tweets_author_created_at"]].apply(pd.to_datetime)

# %%
t_ref = df["created_at"].min()
t_ref
# Out:
# Timestamp('2021-10-07 00:00:00+0000', tz='UTC')

# %%
retweet_counts = df["author_id"].value_counts()
retweet_counts
# Out:
# 1082540114973245440    1881
# 253982124               763
# 1197983394958848000     676
# 406766589               635
# 176618654               613
#                        ...
# 109449512                 1
# 179496334                 1
# 204831114                 1
# 714191831580454914        1
# 1051634101390856193       1
# Name: author_id, Length: 290796, dtype: int64

# %%
authors_id = df["author_id"].unique()
authors_id.shape
# Out:
# (290796,)

# %%
# authors_id = np.array([x for x in df["author_id"].unique() if( retweet_counts[x] >= 30*2 and retweet_counts[x] <= 30*50)])
authors_id = np.array([x for x in df["author_id"].unique() if( retweet_counts[x] >= 30 * 2)])
authors_id.shape
# Out:
# (2577,)

# %%
authors_id[0]
# Out:
# '1081583873291624451'

# %%
referenced_tweets_id = df["referenced_tweets_id"].unique()
referenced_tweets_id.shape
# Out:
# (75619,)

# %%
# def retweet_fuction(row):
#     # if row.empty:
#     #     return 0
#     # elif list(row["created_at"])[0] == time:
#     #     return abs(list(row["referenced_tweets_created_at"])[0] - t_ref)
#     # else:
#     #     return 0
#     return abs(row["referenced_tweets_created_at"] - t_ref)

# %%
# retweet_fuction(1058014331420450817,1445730455966334976,df["created_at"].iloc[1145706])

# %%
# df["referenced_tweets_created_at"].iloc[1145706]

# %%
# df["retweet_fuction"] = df.apply(lambda x: retweet_fuction(x),axis=1)
df["retweet_function"] = df["referenced_tweets_created_at"].apply(lambda x: abs(x-t_ref).total_seconds())

# %%
df
# Out:
#                    author_id                created_at                   id  \
# 0        1417148229053988879 2021-10-07 00:12:23+00:00  1445904805852033026
# 1        1376715806235561984 2021-10-07 00:11:27+00:00  1445904569066786817
# 2        1441084185653829644 2021-10-07 00:12:12+00:00  1445904758074654720
# 3        1386666107994583045 2021-10-07 00:11:20+00:00  1445904541019475969
# 4                  423895213 2021-10-07 00:11:17+00:00  1445904527010369536
# ...                      ...                       ...                  ...
# 1145702           2678455944 2021-10-07 00:00:08+00:00  1445901720026976256
# 1145703            633330070 2021-10-07 00:00:05+00:00  1445901707251175427
# 1145704  1051634101390856193 2021-10-07 00:00:04+00:00  1445901705695088640
# 1145705            316918405 2021-10-07 00:00:02+00:00  1445901696979308550
# 1145706  1058014331420450817 2021-10-07 00:00:00+00:00  1445901686007078913
#
#                                                       text  \
# 0        RT @MarcosRogerio: O relator informou que colo...
# 1        RT @MarcosRogerio: O relator informou que colo...
# 2        RT @MarcosRogerio: O relator informou que colo...
# 3        RT @MarcosRogerio: O relator informou que colo...
# 4        RT @MarcosRogerio: O relator informou que colo...
# ...                                                    ...
# 1145702  RT @GFiuza_Oficial: Mais uma: Sofia, 17 anos, ...
# 1145705  A Suécia interrompe o uso de 💉💉💉 da covid  par...
# 1145706  Infectados são capazes de gerar anticorpos con...
#
#         referenced_tweets_author_created_at referenced_tweets_author_name  \
# 0                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 1                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 2                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 3                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 4                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# ...                                     ...                           ...
# 1145702           2014-10-04 13:20:53+00:00               Guilherme Fiuza
# 1145703           2009-07-21 22:55:27+00:00                Mônica Bergamo
# 1145704           2016-09-02 05:06:27+00:00              Simone Regazio 🚩
# 1145705           2014-10-03 16:22:22+00:00       Verdades e Nada Mais 🔸️
# 1145706           2011-07-25 23:37:38+00:00             🇧🇷Ailton Benedito
#
#         referenced_tweets_author_username  retweet_function
# 0                           MarcosRogerio            2700.0
# 1                           MarcosRogerio            2700.0
# 2                           MarcosRogerio            2700.0
# 3                           MarcosRogerio            2700.0
# 4                           MarcosRogerio            2700.0
# ...                                   ...               ...
# 1145702                    GFiuza_Oficial          269213.0
# 1145703                     monicabergamo            4051.0
# 1145704                     simoneregazio            4402.0
# 1145705                    BarbeariaPoian           39786.0
# 1145706                    AiltonBenedito           40825.0
#
# [1145707 rows x 16 columns]

# %%
time_index = pd.date_range(start=df["created_at"].min(),end=df["created_at"].max(),freq="s")
# time_index = df["created_at"].unique()
time_index.shape
# Out:
# (2671076,)

# %%
df["retweet_function"]
# Out:
# 0            2700.0
# 1            2700.0
# 2            2700.0
# 3            2700.0
# 4            2700.0
#              ...
# 1145702    269213.0
# 1145703      4051.0
# 1145704      4402.0
# 1145705     39786.0
# 1145706     40825.0
# Name: retweet_function, Length: 1145707, dtype: float64

# %%
time_series = pd.Series(np.nan,index=time_index)
time_series
# Out:
# 2021-10-07 00:00:00+00:00   NaN
# 2021-10-07 00:00:01+00:00   NaN
# 2021-10-07 00:00:02+00:00   NaN
# 2021-10-07 00:00:03+00:00   NaN
# 2021-10-07 00:00:04+00:00   NaN
#                              ..
# 2021-11-06 21:57:51+00:00   NaN
# 2021-11-06 21:57:52+00:00   NaN
# 2021-11-06 21:57:53+00:00   NaN
# 2021-11-06 21:57:54+00:00   NaN
# 2021-11-06 21:57:55+00:00   NaN
# Freq: S, Length: 2671076, dtype: float64

# %%
def rle_list(t_series):
    print(t_series)
    s = t_series.fillna('nan')
    mask = s.ne(s.shift())

    ids = s[mask].to_numpy()
    counts = s.groupby(mask.cumsum()).cumcount().add(1).groupby(mask.cumsum()).max().to_numpy()

    # Convert 'nan' string back to `NaN`
    ids[ids == 'nan'] = np.nan
    ser_out = pd.Series(counts, index=ids, name='counts').reset_index()
    print(ser_out)
    return np.where(ser_out["index"].isna(),-ser_out["counts"],ser_out["index"])
    # list = []
    # for index,value in ser_out.iteritems():
    #     if index == 'nan':
    #         list.append(int(-value))
    #     else:
    #         list.append(int(index.total_seconds()))
    # return list

# %%
time_series = pd.Series(np.nan,index=time_index).reset_index()
time_series
# Out:
#                             index   0
# 0       2021-10-07 00:00:00+00:00 NaN
# 1       2021-10-07 00:00:01+00:00 NaN
# 2       2021-10-07 00:00:02+00:00 NaN
# 3       2021-10-07 00:00:03+00:00 NaN
# 4       2021-10-07 00:00:04+00:00 NaN
# ...                           ...  ..
# 2671071 2021-11-06 21:57:51+00:00 NaN
# 2671072 2021-11-06 21:57:52+00:00 NaN
# 2671073 2021-11-06 21:57:53+00:00 NaN
# 2671074 2021-11-06 21:57:54+00:00 NaN
# 2671075 2021-11-06 21:57:55+00:00 NaN
#
# [2671076 rows x 2 columns]

# %%
tt = time_series.merge(df[["author_id","created_at","retweet_function"]].query("author_id == '178080027'"),left_on="index",right_on="created_at",how="left")
# rows = df[df.author_id == author]
# for _,row in rows.iterrows():
#     time_series[row["created_at"]] = row["retweet_fuction"]

# %%
tt = tt[["index","retweet_function"]].set_index("index")

# %%
rle_list(tt["retweet_function"])
# Out:
# index
# 2021-10-07 00:00:00+00:00   NaN
# 2021-10-07 00:00:01+00:00   NaN
# 2021-10-07 00:00:02+00:00   NaN
# 2021-10-07 00:00:03+00:00   NaN
# 2021-10-07 00:00:04+00:00   NaN
#                              ..
# 2021-11-06 21:57:51+00:00   NaN
# 2021-11-06 21:57:52+00:00   NaN
# 2021-11-06 21:57:53+00:00   NaN
# 2021-11-06 21:57:54+00:00   NaN
# 2021-11-06 21:57:55+00:00   NaN
# Name: retweet_function, Length: 2671076, dtype: float64
#          index  counts
# 0          NaN    2695
# 1      14398.0       1
# 2          NaN     548
# 3        823.0       1
# 4          NaN      49
# ..         ...     ...
# 146        NaN   37426
# 147  2423152.0       1
# 148        NaN   57662
# 149  2496110.0       1
# 150        NaN  169726
#
# [151 rows x 2 columns]
# array([-2.695000e+03,  1.439800e+04, -5.480000e+02,  8.230000e+02,
#        -4.900000e+01,  1.757800e+04, -1.359900e+04,  2.803500e+04,
#        -3.760000e+02,  1.969100e+04, -4.429500e+04,  6.123600e+04,
#        -1.530000e+02,  5.227200e+04, -4.059000e+04,  1.020520e+05,
#        -1.880000e+02,  4.857800e+04, -4.539700e+04,  1.446650e+05,
#        -4.533100e+04,  1.566040e+05, -2.687400e+04,  2.156670e+05,
#        -1.007680e+05,  2.715590e+05, -3.413600e+04,  2.067790e+05,
#        -2.129300e+04,  3.204040e+05, -8.523000e+04,  4.162250e+05,
#        -5.035700e+04,  5.094970e+05, -9.975400e+04,  5.754860e+05,
#        -1.290900e+04,  5.354440e+05, -3.940000e+03,  5.967080e+05,
#        -3.000000e+00,  5.967080e+05, -3.193800e+04,  6.603940e+05,
#        -6.785700e+04,  6.819680e+05, -1.696000e+03,  7.268020e+05,
#        -1.430000e+02,  6.951700e+05, -5.638400e+04,  7.646130e+05,
#        -7.342500e+04,  8.598850e+05, -1.790000e+02,  8.569280e+05,
#        -3.407000e+04,  5.684440e+05, -2.800000e+02,  8.679320e+05,
#        -1.780000e+02,  8.680620e+05, -6.771000e+04,  9.312890e+05,
#        -5.354300e+04,  1.011448e+06, -4.400000e+01,  1.011066e+06,
#        -4.274200e+04,  1.026062e+06, -4.682000e+03,  1.021918e+06,
#        -1.194000e+03,  1.050474e+06, -5.660000e+02,  1.038367e+06,
#        -5.202500e+04,  1.115419e+06, -4.720000e+02,  1.102332e+06,
#        -8.458300e+04,  1.188392e+06, -2.460000e+02,  1.166147e+06,
#        -7.400000e+01,  1.121415e+06, -1.769990e+05,  1.202843e+06,
#        -4.180000e+02,  1.258330e+06, -6.082100e+04,  1.366845e+06,
#        -5.552700e+04,  1.432125e+06, -3.055700e+04,  1.467824e+06,
#        -5.486000e+03,  1.511087e+06, -8.792700e+04,  1.609668e+06,
#        -6.525000e+03,  1.626671e+06, -5.030000e+02,  1.593916e+06,
#        -1.689100e+04,  1.620437e+06, -1.587300e+04,  1.654406e+06,
#        -5.330000e+02,  1.631526e+06, -4.328500e+04,  1.701873e+06,
#        -7.287000e+03,  1.707082e+06, -2.286000e+03,  1.712931e+06,
#        -3.161000e+04,  1.702037e+06, -7.572000e+03,  1.730700e+06,
#        -3.365500e+04,  5.754860e+05, -2.406800e+04,  1.803733e+06,
#        -1.834300e+04,  1.807874e+06, -6.200000e+01,  1.811433e+06,
#        -3.450000e+02,  1.816894e+06, -1.081320e+05,  1.894615e+06,
#        -2.159760e+05,  2.117822e+06, -2.300900e+04,  2.120403e+06,
#        -4.650000e+02,  2.175599e+06, -7.880000e+02,  2.165470e+06,
#        -2.851000e+03,  2.153885e+06, -7.609400e+04,  2.253475e+06,
#        -1.497830e+05,  2.403743e+06, -3.742600e+04,  2.423152e+06,
#        -5.766200e+04,  2.496110e+06, -1.697260e+05])

# %%
# rle_list(time_series)
def calculate_series(author,df_temp):
    time_series = pd.Series(np.nan,index=time_index).reset_index()

    # rows = df.loc[df["author_id"].isin([author])]
    # rows = df[df.author_id == author]
    # for _,row in df_temp.iterrows():
    #     time_series[row["created_at"]] = row["retweet_fuction"]

    time_series = time_series.merge(df_temp[["author_id","created_at","retweet_function"]],left_on="index",right_on="created_at",how="left").set_index("index")
    time_series = time_series["retweet_function"]
        
    time_list = rle_list(time_series)
    pd.DataFrame(time_list).to_csv("time_series/" + str(author) + ".csv",header=None,index=None) 
    return time_list

# %%
df
# Out:
#                    author_id                created_at                   id  \
# 0        1417148229053988879 2021-10-07 00:12:23+00:00  1445904805852033026
# 1        1376715806235561984 2021-10-07 00:11:27+00:00  1445904569066786817
# 2        1441084185653829644 2021-10-07 00:12:12+00:00  1445904758074654720
# 3        1386666107994583045 2021-10-07 00:11:20+00:00  1445904541019475969
# 3                          160895960    2021-10-06 23:15:00+00:00
# 4                          160895960    2021-10-06 23:15:00+00:00
# ...                              ...                          ...
# 1145702                   2804949532    2021-10-03 21:13:07+00:00
# 1145703                     58951368    2021-10-06 22:52:29+00:00
# 1145704           771574989195575302    2021-10-06 22:46:38+00:00
# 1145705                   2802207875    2021-10-06 12:56:54+00:00
# 1145706                    342403919    2021-10-06 12:39:35+00:00
#
#                                     referenced_tweets_text  \
# 0        O relator informou que colocará o presidente d...
# 1        O relator informou que colocará o presidente d...
# 2        O relator informou que colocará o presidente d...
# 3        O relator informou que colocará o presidente d...
# 4        O relator informou que colocará o presidente d...
# ...                                                    ...
# 1145702  Mais uma: Sofia, 17 anos, estudante saudável, ...
# 1145703  O "kit Covid", pacote de remédios ineficazes c...
# 1145704  Meu amor vcs aplaudiram reunião  com Amado Bat...
# 1145705  A Suécia interrompe o uso de 💉💉💉 da covid  par...
# 1145706  Infectados são capazes de gerar anticorpos con...
#
#         referenced_tweets_author_created_at referenced_tweets_author_name  \
# 0                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 1                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 2                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 3                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# 4                 2010-06-29 12:04:57+00:00                MARCOS ROGÉRIO
# ...                                     ...                           ...
# 1145702           2014-10-04 13:20:53+00:00               Guilherme Fiuza
# 1145703           2009-07-21 22:55:27+00:00                Mônica Bergamo
# 1145704           2016-09-02 05:06:27+00:00              Simone Regazio 🚩
# 1145705           2014-10-03 16:22:22+00:00       Verdades e Nada Mais 🔸️
# 1145706           2011-07-25 23:37:38+00:00             🇧🇷Ailton Benedito
#
#         referenced_tweets_author_username  retweet_function
# 0                           MarcosRogerio            2700.0
# 1                           MarcosRogerio            2700.0
# 2                           MarcosRogerio            2700.0
# 3                           MarcosRogerio            2700.0
# 4                           MarcosRogerio            2700.0
# ...                                   ...               ...
# 1145702                    GFiuza_Oficial          269213.0
# 1145703                     monicabergamo            4051.0
# 1145704                     simoneregazio            4402.0
# 1145705                    BarbeariaPoian           39786.0
# 1145706                    AiltonBenedito           40825.0
#
# [1145707 rows x 16 columns]

# %%
df_filtered = df[df["author_id"].isin(authors_id)].copy()

# %%
len(list(df_filtered.groupby("author_id")))
# Out:
# 2577

# %%
from joblib import Parallel, delayed
from tqdm import tqdm
tqdm.pandas()
# input = tqdm(authors_id)
df_grouped = df_filtered.groupby("author_id")
# df_list = list(df.groupby("author_id"))
# df_grouped = df_list[:3]

series = Parallel(n_jobs=-1)(delayed(calculate_series)(author,df_temp) for author,df_temp in tqdm(df_grouped))
# Out:
#  22%|██▏       | 560/2577 [05:23<20:45,  1.62it/s]

# %%
import csv

with open("out.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(series)
